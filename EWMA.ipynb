# %%
#https://ai.plainenglish.io/how-to-implement-ewma-plots-using-python-8a158e5bab48
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('dataset_14_08_2002.csv') #20190105_clean #dataset_14_08_2002
df.head()

#Creating SMA (Simple Moving Average)
"""df['6SMA'] = df['GB'].rolling(window=6).mean()
df.head()
df['12SMA'] = df['GB'].rolling(window=12).mean()
df.head()
df.plot()"""

#Creating EWMA (Exponentially Weighted Moving Average)
df['6EWMA'] = df['GB'].ewm(span=6).mean()
df['12EWMA'] = df['GB'].ewm(span=12).mean()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('dataset_14_08_2002.csv') #20190105_clean #dataset_14_08_2002
df.head()
df['Error6EWMA'] = df['GB'].ewm(span=1).mean() - df['GB'].ewm(span=6).mean()
df['Error6EWMA'].plot()
# Out:
# <AxesSubplot:>
